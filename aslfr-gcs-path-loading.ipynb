# %%
import numpy as np
from kaggle_datasets import KaggleDatasets
import pandas as pd

# %% [markdown]
# # GCS-path

# %%
print(f"'supply-pid': '{KaggleDatasets().get_gcs_path('supply-pid')}'")
print(f"'supply-mean-std': '{KaggleDatasets().get_gcs_path('supply-mean-std')}'")

# %%
print(f"'participant-id-all-train': '{KaggleDatasets().get_gcs_path('participant-id-all-train')}'")

# %%
print(f"'ASL': '{KaggleDatasets().get_gcs_path('asl-fingerspelling')}'")
# print(f"'Participant_id': '{KaggleDatasets().get_gcs_path('pid-distribuion-tfds')}'")
print(f"'new-coordinate-mean-std': '{KaggleDatasets().get_gcs_path('new-coordinate-mean-std')}'")

# %%
print(f"'1%-val-dataset': '{KaggleDatasets().get_gcs_path('1-origin-val-set')}'")
print(f"'1%-train-dataset': '{KaggleDatasets().get_gcs_path('1-precent-training-set')}'")

# %%
print(f"'5%-val-dataset': '{KaggleDatasets().get_gcs_path('5precent-origin-val-set')}'")
print(f"'5%-train-dataset': '{KaggleDatasets().get_gcs_path('5-precent-train-set')}'")

# %%
print(f"'tfrecords-adddata3-public': '{KaggleDatasets().get_gcs_path('tfrecords-adddata3-public')}'")
print(f"'tfrecords-adddata2-public': '{KaggleDatasets().get_gcs_path('tfrecords-adddata2-public')}'")
print(f"'tfrecords-adddata1-public': '{KaggleDatasets().get_gcs_path('tfrecords-adddata1-public')}'")
print(f"'tfrecordsuppledata': '{KaggleDatasets().get_gcs_path('tfrecordsuppledata')}'")

# %%
print(f"'url-10-pre-training': '{KaggleDatasets().get_gcs_path('url-10-pre-training')}'")
